# %%
# SOLVED EXAMPLE
# --------------
# Question: Check if a variable is None
print("SOLVED EXAMPLE:")
print("Check if a variable is None")
variable = None
is_none = variable is None
print(f"Variable: {variable}")
print(f"Is None: {is_none}")
# Out:
# SOLVED EXAMPLE:
# Check if a variable is None
# Variable: None
# Is None: True

# %%
# Question 1: Create a variable and assign None to it
print("Question 1: Create a variable and assign None to it")
# Your code here
variable1=(None,None,None)
print(variable1)
print(type(variable1))
# Out:
# Question 1: Create a variable and assign None to it
# [None, None, None]
# <class 'list'>

# %%
# Question 2: Check if None equals None
print("\nQuestion 2: Check if None equals None")
# Your code here
variable1="None"
variable2="None"
if variable1==variable2:
  print(True)
else:
  print(False)
# Out:
# Question 2: Check if None equals None
# True

# %%
# Question 3: Check if None is None
print("\nQuestion 3: Check if None is None")
# Your code here
if None is None:
  print("Yes, None is None")
else:
  print("NO, None is not NOne")
# Out:
# Question 3: Check if None is None
# Yes, None is None

# %%
# Question 4: Check if 0 is None
print("\nQuestion 4: Check if 0 is None")
# Your code here
if 0 == None:
  print("Yes, 0 is None")
else:
  print("NO, 0 is not None")
# Out:
# Question 4: Check if 0 is None
# NO, 0 is not None

# %%
# Question 5: Check if empty string is None
print("\nQuestion 5: Check if empty string is None")
# Your code here
variable1=" "
variable2=None
if variable1==variable2:
  print(True)
else:
  print(False)
# Out:
# Question 5: Check if empty string is None
# False

# %%
# Question 6: Check if False is None
print("\nQuestion 6: Check if False is None")
# Your code here
if False is None:
  print(True)
else:
  print(False)
# Out:
# Question 6: Check if False is None
# False

# %%
# Question 7: Check if empty list is None
print("\nQuestion 7: Check if empty list is None")
# Your code here
variable1=[ ]
variable2=None
if variable1==variable2:
  print("Yes, empty list is none")
else:
  print("No, empty list is not none")
# Out:
# Question 7: Check if empty list is None
# No, empty list is not none

# %%
# Question 8: Check if empty dictionary is None
print("\nQuestion 8: Check if empty dictionary is None")
# Your code here
variable1=set()
variable2=None
if variable1==variable2:
  print("Yes, empty dictionary is none")
else:
  print("No, empty dictionary is not none")
# Out:
# Question 8: Check if empty dictionary is None
# No, empty dictionary is not none

# %%
# Question 9: Check if empty tuple is None
print("\nQuestion 9: Check if empty tuple is None")
# Your code here
variable1=()
variable2=None
if variable1==variable2:
  print("Yes, empty tuple is none")
else:
  print("No, empty tuple is not none")
# Out:
# Question 9: Check if empty tuple is None
# No, empty tuple is not none

# %%
# Question 10: Check if empty set is None
print("\nQuestion 10: Check if empty set is None")
# Your code here
variable1={}
variable2=None
if variable1==variable2:
  print("Yes, empty set is none")
else:
  print("No, empty set is not none")
# Out:
# Question 10: Check if empty set is None
# No, empty set is not none
