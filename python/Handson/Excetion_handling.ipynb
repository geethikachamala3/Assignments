# %%
print("before")
age=int(input("Enter you age: "))
print(age)
print("after")
# Out:
# before
# Enter you age: 22
# 22
# after

# %%
#try except block is used to catch and handle exception
print("befor executing")
try:
  age=int(input("Enter you age: "))
  print()
except ValueError:
  print("This error occured while entering age")
print("After executing")
# Out:
# befor executing
# Enter you age:
# This error occured while entering age
# After executing

# %%
##basic synytax
try:
  #code that might raise an expection
  risky_operation()
except exceptiontype:
  #code to handle the exception
  handle_error()

# %%
try:
  number=int(input("Enter a number: "))
  result=10/number
  print(f"Result: {result}")
except ZeroDivisionError:
  print("Error: Cannot divide by zero")
except ValueError :
  print("Error: Please enter a valid number")
# Out:
# Enter a number: 0
# Error: Cannot divide by zero

# %%
try:
  x=10/"dlfjv"
except Exception as e:
  print(f"An error occured: {e}")
# Out:
# An error occured: unsupported operand type(s) for /: 'int' and 'str'

# %%
#we can handle multiple exceptions in different ways
try:
  data=[1,2,3]
  index=int(input("Enter index: "))
  print(data(index))
except IndexError:
  print("Error: Index given out of range")
except ValueError:
  print("Error: Invaild input! please enter an integer")
except Exception as e:
  print(f"Unexpected error: {e}")
# Out:
# Enter index: 3
# Unexpected error: 'list' object is not callable

# %%
#tuple of exception
try:
  value=int(input("Enter a number: "))
  result=100/value
except (ValueError. ZeroDivisionError) as e:
  print(f"Input or calculation error: {e}")
# Out:
# Enter a number: 5

# %%
#getting exception details
try:
  file=open("non_existent_file.txt", "r")
except FileNotFoundError as e:
  print(f"File error: {e}")
  print(f"Error type: {type(e).__name__}")
# Out:
# File error: [Errno 2] No such file or directory: 'non_existent_file.txt'
# Error type: FileNotFoundError

# %%
#finally clause
try:
  ##code that might raise an error
  operation()
except ExceptiomType:
  #handle exception
  Handler_error()
finally:
  #always execute this error occured while entering age
  cleanup()

# %%
file=None
try:
  file=open("Data.txt","r")
  content=file.read()
  print(content)
except FileNotFoundError:
  print("File not found")
finally:
  if file:
    file.close()
    print("File closed successfully...")

# %%
#else clause
try:
    # code that might crash
    operation()
except Exception Type:
    # handle exception
    handle_error()
else:
    # Excute only if no exception occured
    Success_operation()
finally:
    # always executes
    cleanup()

# %%
#division calculator
try:
  num1=float(input("Enter first number: "))
  num2=float(input("Enter second number: "))
  result=num1/num2
except ValueError:
  print("Invalid input: please enter number")
except ZeroDivisionError:
  print("Cannot be divide by zero")
else:
  print(f"REsult: {result}")
  print("Calculation successful")
finally:
  print("Calculator closed")
# Out:
# Enter first number: 223.3
# Enter second number: 233.6
# REsult: 0.9559075342465754
# Calculation successful
# Calculator closed
